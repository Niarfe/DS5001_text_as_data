# %% [markdown]
# # Module 2: Text into Data: Importing a Text
#
# ## Efrain Olivares: dpy8wq
#
# * DS 5001: Exploratory Text Analytics
# * Raf Alvarado

# %% [markdown]
# # Set Up

# %%
epub_file = "pg161-1.txt"
csv_file = 'austen-sense-and-sensibility.csv'

# %%
OHCO = ['chap_num', 'para_num', 'sent_num', 'token_num']

# %%
import pandas as pd
# %matplotlib inline

# %% [markdown]
# # Import file into a dataframe

# %%
epub = open(epub_file, 'r', encoding='utf-8-sig').readlines()
df = pd.DataFrame(epub, columns=['line_str'])
df.index.name = 'line_num'
df.line_str = df.line_str.str.strip()

# %%
df.sample(10)
# Out:
#                                                    line_str
# line_num
# 10580
# 11235     however, he is quite mistaken.  His age is onl...
# 10993     irreparable injury which too early an independ...
# 12784                                                1.E.9.
# 1800      succeeded by such opinions as are but too comm...
# 2750      sunk within a few days into a calmer melanchol...
# 8599      Her narration was clear and simple; and though...
# 7306      finally arranged by his own inventive fancy, h...
# 6106      "I can have no pleasure while I see you in thi...
# 9393      him farther, I must think very differently of ...

# %% [markdown]
# # Extract title of work from first line

# %%
title = df.loc[0].line_str.replace('The Project Gutenberg EBook of ', '')
df['title'] = title

# %%
print(title)
# Out:
# ﻿Sense and Sensibility, by Jane Austen

# %%
df.head()
# Out:
#                                                    line_str  \
# line_num
# 0         ﻿The Project Gutenberg EBook of Sense and Sens...
# 1
# 2         This eBook is for the use of anyone anywhere a...
# 3         almost no restrictions whatsoever.  You may co...
# 4         re-use it under the terms of the Project Guten...
#
#                                            title
# line_num
# 0         ﻿Sense and Sensibility, by Jane Austen
# 1         ﻿Sense and Sensibility, by Jane Austen
# 2         ﻿Sense and Sensibility, by Jane Austen
# 3         ﻿Sense and Sensibility, by Jane Austen
# 4         ﻿Sense and Sensibility, by Jane Austen

# %% [markdown]
# # Remove Gutenberg's front and back matter

# %%
a = df.line_str.str.match(r"\*\*\*\s*START OF (THE|THIS) PROJECT")
b = df.line_str.str.match(r"\*\*\*\s*END OF (THE|THIS) PROJECT")

# %%
an = df.loc[a].index[0]
bn = df.loc[b].index[0]

# %%
df = df.loc[an + 1 : bn - 2]

# %%
df
# Out:
#                                                    line_str  \
# line_num
# 19
# 20        Special thanks are due to Sharon Partridge for...
# 21               proofreading and correction of this etext.
# 22
# 23
# ...                                                     ...
# 12662
# 12663
# 12664
# 12665
# 12666     End of the Project Gutenberg EBook of Sense an...
#
#                                            title
# line_num
# 19        ﻿Sense and Sensibility, by Jane Austen
# 20        ﻿Sense and Sensibility, by Jane Austen
# 21        ﻿Sense and Sensibility, by Jane Austen
# 22        ﻿Sense and Sensibility, by Jane Austen
# 23        ﻿Sense and Sensibility, by Jane Austen
# ...                                          ...
# 12662     ﻿Sense and Sensibility, by Jane Austen
# 12663     ﻿Sense and Sensibility, by Jane Austen
# 7602      CHAPTER 34  ﻿Sense and Sensibility, by Jane Austen
# 7889      CHAPTER 35  ﻿Sense and Sensibility, by Jane Austen
# 8153      CHAPTER 36  ﻿Sense and Sensibility, by Jane Austen
# 8457      CHAPTER 37  ﻿Sense and Sensibility, by Jane Austen
# 8901      CHAPTER 38  ﻿Sense and Sensibility, by Jane Austen
# 9206      CHAPTER 39  ﻿Sense and Sensibility, by Jane Austen
# 9409      CHAPTER 40  ﻿Sense and Sensibility, by Jane Austen
# 9707      CHAPTER 41  ﻿Sense and Sensibility, by Jane Austen
# 9978      CHAPTER 42  ﻿Sense and Sensibility, by Jane Austen
# 10156     CHAPTER 43  ﻿Sense and Sensibility, by Jane Austen
# 10491     CHAPTER 44  ﻿Sense and Sensibility, by Jane Austen
# 11061     CHAPTER 45  ﻿Sense and Sensibility, by Jane Austen
# 11279     CHAPTER 46  ﻿Sense and Sensibility, by Jane Austen
# 11572     CHAPTER 47  ﻿Sense and Sensibility, by Jane Austen
# 11839     CHAPTER 48  ﻿Sense and Sensibility, by Jane Austen
# 11987     CHAPTER 49  ﻿Sense and Sensibility, by Jane Austen
# 12411     CHAPTER 50  ﻿Sense and Sensibility, by Jane Austen

# %% [markdown]
# ## Assign numbers to chapters

# %%
chap_nums = [i+1 for i in range(df.loc[chap_lines].shape[0])]

# %%
df.loc[chap_lines, 'chap_num'] = chap_nums

# %% [markdown]
# ## Forward-fill chapter numbers to following text lines

# %%
df.chap_num = df.chap_num.ffill()

# %% [markdown]
# ## Clean up

# %%
df = df.loc[~df.chap_num.isna()] # Remove chapter heading lines
df = df.loc[~chap_lines] # Remove everything before Chapter 1
df.chap_num = df.chap_num.astype('int') # Convert chap_num from float to int

# %%
df.sample(10)
# Out:
#                                                    line_str  \
# line_num
# 9876      was exceedingly pleased to hear that Mrs. Ferr...
# 2458      Surprised and alarmed they proceeded directly ...
# 1837
# 2355                                      perfect with him.
# 4821      from every expression that could give her word...
# 11654
# 6511      "Ay, if we can do THAT, Ma'am," said Elinor, "...
# 3748                        any one to him except his wife.
# 917             we will plan our improvements accordingly."
# 6388      follow her, she directly got up and hurried ou...
#
#                                            title  chap_num
# line_num
# 9876      ﻿Sense and Sensibility, by Jane Austen        41
# 2458      ﻿Sense and Sensibility, by Jane Austen        15
# 1837      ﻿Sense and Sensibility, by Jane Austen        12
# 2355      ﻿Sense and Sensibility, by Jane Austen        14
# 4821      ﻿Sense and Sensibility, by Jane Austen        24
# 11654     ﻿Sense and Sensibility, by Jane Austen        47
# 6511      ﻿Sense and Sensibility, by Jane Austen        30
# 3748      ﻿Sense and Sensibility, by Jane Austen        20
# 917       ﻿Sense and Sensibility, by Jane Austen         6
# 6388      ﻿Sense and Sensibility, by Jane Austen        30

# %% [markdown]
# ## Group lines by chapter num

# %%
dfc = df.groupby(OHCO[:1]).line_str.apply(lambda x: '\n'.join(x)).to_frame() # Make big string

# %%
dfc.head()
# Out:
#                                                    line_str
# chap_num
# 1         \n\nThe family of Dashwood had long been settl...
# 2         \n\nMrs. John Dashwood now installed herself m...
# 3         \n\nMrs. Dashwood remained at Norland several ...
# 4         \n\n"What a pity it is, Elinor," said Marianne...
# 5         \n\nNo sooner was her answer dispatched, than ...

# %% [markdown]
# # Split into paragraphs

# %%
dfp = dfc['line_str'].str.split(r'\n\n+', expand=True).stack()\
    .to_frame().rename(columns={0:'para_str'})

# %%
dfp.head()
# Out:
#                                                      para_str
# chap_num
# 1        0
#          1  The family of Dashwood had long been settled i...
#          2  By a former marriage, Mr. Henry Dashwood had o...
#          3  The old gentleman died: his will was read, and...
#          4  Mr. Dashwood's disappointment was, at first, s...

# %%
dfp.index.names = OHCO[:2]

# %%
dfp.head()
# Out:
#                                                             para_str
# chap_num para_num
# 1        0
#          1         The family of Dashwood had long been settled i...
#          2         By a former marriage, Mr. Henry Dashwood had o...
#          3         The old gentleman died: his will was read, and...
#          4         Mr. Dashwood's disappointment was, at first, s...

# %%
dfp['para_str'] = dfp['para_str'].str.replace(r'\n', ' ').str.strip()
dfp = dfp[~dfp['para_str'].str.match(r'^\s*$')] # Remove empty paragraphs

# %%
dfp.head()
# Out:
#                                                             para_str
# chap_num para_num
# 1        1         The family of Dashwood had long been settled i...
#          2         By a former marriage, Mr. Henry Dashwood had o...
#          3         The old gentleman died: his will was read, and...
#          4         Mr. Dashwood's disappointment was, at first, s...
#          5         His son was sent for as soon as his danger was...

# %% [markdown]
# # Split into sentences
#
# NOTE: ADDED `"` to regex in `split()`

# %%
dfs = dfp['para_str'].str.split(r'[.?!;:"]+', expand=True).stack()\
    .to_frame().rename(columns={0:'sent_str'})

# %%
dfs.index.names = OHCO[:3]

# %%
dfs = dfs[~dfs['sent_str'].str.match(r'^\s*$')] # Remove empty paragraphs

# %%
dfs.head()
# Out:
#                                                                      sent_str
# chap_num para_num sent_num
# 1        1        0         The family of Dashwood had long been settled i...
#                   1           Their estate\nwas large, and their residence...
#                   2           The late owner of this estate was a single\n...
#                   3           But her\ndeath, which happened ten years bef...
#                   4          for to supply her loss, he invited and receiv...

# %% [markdown]
# # Split into tokens

# %%
dft = dfs['sent_str'].str.split(r"[\s',-]+", expand=True).stack()\
    .to_frame().rename(columns={0:'token_str'})

# %%
dft.index.names = OHCO[:4]

# %%
dft.head()
# Out:
#                                      token_str
# chap_num para_num sent_num token_num
# 1        1        0        0               The
#                            1            family
#                            2                of
#                            3          Dashwood
#                            4               had

# %% [markdown]
# # Gathering by Content Object

# %%
sents = dft.groupby(OHCO[:3]).token_str.apply(lambda x: ' '.join(x)).to_frame().rename(columns={'token_str':'content'})
paras = dft.groupby(OHCO[:2]).token_str.apply(lambda x: ' '.join(x)).to_frame().rename(columns={'token_str':'content'})
chaps = dft.groupby(OHCO[:1]).token_str.apply(lambda x: ' '.join(x)).to_frame().rename(columns={'token_str':'content'})

# %%
def gather(ohco_level):
    return df.groupby(OHCO[:ohco_level]).token_str\
        .apply(lambda x: ' '.join(x))\
        .to_frame()\
        .rename(columns={'token_str':'content'})

# %%
sents.sample(10)
# Out:
#                                                                       content
# chap_num para_num sent_num
# 6        10       0         An opportunity was soon to be given to the Das...
# 25       16       8          she would perhaps expect some from improving ...
# 33       11       4          they are people of large fortune they are rel...
# 31       10       6          Jennings s going away remained fixed at the t...
# 1        8        1                He then really thought himself equal to it
# 2        24       14               Only conceive how comfortable they will be
# 16       12       2          our dear Willoughby went away before we could...
# 3        6        3          but when his natural shyness was overcome his...
# 13       64       5          and when I come to see you I hope you will ha...
# 3        20       6                                         I require so much

# %%
dft.token_str.str.len().plot.hist(bins=10, title="Tokens")
# Out:
# <Axes: title={'center': 'Tokens'}, ylabel='Frequency'>

# %%
sents.content.str.len().plot.hist(bins=20, title='Sentences')
# Out:
# <Axes: title={'center': 'Sentences'}, ylabel='Frequency'>

# %%
paras.content.str.len().plot.hist(title="Paragraphs")
# Out:
# <Axes: title={'center': 'Paragraphs'}, ylabel='Frequency'>

# %%
chaps.content.str.len().plot.hist(title="Chapters")
# Out:
# <Axes: title={'center': 'Chapters'}, ylabel='Frequency'>

# %% [markdown]
# # Save work to CSV

# %%
dft.to_csv(csv_file)

# %% [markdown]
# # Part 2.  Combine Sense and Sensibility OHCO and Persuasion OHCO into one csv

# %%
df_persuasion = pd.read_csv('austen-persuasion.csv')
df_persuasion.head()
# Out:
#    chap_num  para_num  sent_num  token_num token_str
# 0         1         1         0          0       Sir
# 1         1         1         0          1    Walter
# 2         1         1         0          2    Elliot
# 3         1         1         0          3        of
# 4         1         1         0          4  Kellynch

# %%
book_id_1 = '161'
book_id_2 = '105'

# %%
pers_cols = list(df_persuasion.columns)
df_persuasion['book_id'] = book_id_2
df_persuasion = df_persuasion[['book_id'] + pers_cols]
df_persuasion.head()
# Out:
#   book_id  chap_num  para_num  sent_num  token_num token_str
# 0     105         1         1         0          0       Sir
# 1     105         1         1         0          1    Walter
# 2     105         1         1         0          2    Elliot
# 3     105         1         1         0          3        of
# 4     105         1         1         0          4  Kellynch

# %%
dft = list(dft.columns)
dft['book_id'] = book_id_1
dft = dtf[['book_id'] + pers_cols]
dft.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[56], line 2
#       1 dft = list(dft.columns)
# ----> 2 dft['book_id'] = book_id_1
#       3 dft = dtf[['book_id'] + pers_cols]
#       4 dft.head()
#
# TypeError: list indices must be integers or slices, not str

# %%
dft.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 dft.head()
#
# AttributeError: 'list' object has no attribute 'head'
